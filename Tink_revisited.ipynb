# %% [markdown]
# # Naïve Bayes Classifier

# %% [markdown]
# ## Import the necessary libraires

# %%
import pandas as pd

### ENTER YOUR CODE HERE ###

# %% [markdown]
# ## Read the data

# %%
data = pd.read_csv('tink.csv', encoding = "ISO-8859-1")
data.head()
# Out:
#   CLASS                                            CONTENT
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  INTP  'Good one  _____   https://www.youtube.com/wat...
# 2  INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 3  INTJ  '18/37 @.@|||Science  is not perfect. No scien...
# 4  INFJ  'No, I can't draw on my own nails (haha). Thos...

# %%
data['CLASS'].value_counts()
# Out:
# CLASS
# INFP    1832
# INFJ    1470
# INTP    1304
# INTJ    1091
# Name: count, dtype: int64

# %% [markdown]
# Enter the rest of the code below.

# %%
inputs = data['CONTENT']
target = data['CLASS']
from sklearn.feature_extraction.text import CountVectorizer
CountVectorizer=CountVectorizer()
CountVectorizer.fit_transform(inputs)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs,target , train_size=0.8,random_state=365
                                                     ,stratify=target)
x_train_transform = CountVectorizer.fit_transform(x_train)
x_test_transform = CountVectorizer.transform(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(x_train_transform,y_train)
y_pred=clf.predict(x_test_transform)
from sklearn.metrics import ConfusionMatrixDisplay 
ConfusionMatrixDisplay.from_predictions(
    y_test , y_pred 
)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         INFJ       0.60      0.56      0.58       294
#         INFP       0.54      0.83      0.65       367
#         INTJ       0.81      0.26      0.39       218
#         INTP       0.67      0.58      0.62       261
#
#     accuracy                           0.59      1140
#    macro avg       0.65      0.56      0.56      1140
# weighted avg       0.63      0.59      0.58      1140

# %%
from sklearn.naive_bayes import ComplementNB
clf = ComplementNB()
clf.fit(x_train_transform,y_train)
y_pred=clf.predict(x_test_transform)
from sklearn.metrics import ConfusionMatrixDisplay 
ConfusionMatrixDisplay.from_predictions(
    y_test , y_pred 
)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         INFJ       0.72      0.62      0.67       294
#         INFP       0.64      0.83      0.72       367
#         INTJ       0.78      0.54      0.64       218
#         INTP       0.71      0.70      0.71       261
#
#     accuracy                           0.69      1140
#    macro avg       0.71      0.67      0.68      1140
# weighted avg       0.70      0.69      0.69      1140
